# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style("dark")
sns.set_theme(font_scale=1.5)

# %%
sinc_window = np.fromfile("../testdata/sinc_window_got", dtype=np.float64)
plt.scatter(np.arange(len(sinc_window)), sinc_window)
